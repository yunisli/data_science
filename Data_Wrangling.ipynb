# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod1.csv"
df=pd.read_csv(filepath,header=0)

# %%
df
# Out:
#      Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0             0         Acer         4  IPS Panel    2   1         5
# 1             1         Dell         3    Full HD    1   1         3
# 2             2         Dell         3    Full HD    1   1         7
# 3             3         Dell         4  IPS Panel    2   1         5
# 4             4           HP         4    Full HD    2   1         7
# ..          ...          ...       ...        ...  ...  ..       ...
# 233         233       Lenovo         4  IPS Panel    2   1         7
# 234         234      Toshiba         3    Full HD    2   1         5
# 235         235       Lenovo         4  IPS Panel    2   1         5
# 236         236       Lenovo         3    Full HD    3   1         5
# 237         237      Toshiba         3    Full HD    2   1         5
#
#      Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      238 non-null    int64
#  1   Manufacturer    238 non-null    object
#  2   Category        238 non-null    int64
#  3   Screen          238 non-null    object
#  4   GPU             238 non-null    int64
#  5   OS              238 non-null    int64
#  6   CPU_core        238 non-null    int64
#  7   Screen_Size_cm  234 non-null    float64
#  8   CPU_frequency   238 non-null    float64
#  9   RAM_GB          238 non-null    int64
#  10  Storage_GB_SSD  238 non-null    int64
#  11  Weight_kg       233 non-null    float64
#  12  Price           238 non-null    int64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 24.3+ KB

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# Manufacturer       object
# Category            int64
# Screen             object
# GPU                 int64
# OS                  int64
# CPU_core            int64
# Screen_Size_cm    float64
# CPU_frequency     float64
# RAM_GB              int64
# Storage_GB_SSD      int64
# Weight_kg         float64
# Price               int64
# dtype: object

# %%
df.value_counts()
# Out:
# Unnamed: 0  Manufacturer  Category  Screen     GPU  OS  CPU_core  Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0           Acer          4         IPS Panel  2    1   5         35.560          1.6            8       256             1.60       978      1
# 150         Lenovo        3         IPS Panel  2    1   5         35.560          2.5            8       256             1.70       1872     1
# 153         Toshiba       3         IPS Panel  2    1   7         38.100          2.5            8       256             2.20       1777     1
# 154         Dell          3         Full HD    1    2   5         39.624          2.5            4       128             2.18       723      1
# 155         Lenovo        3         Full HD    2    1   5         35.560          2.3            8       256             1.65       1861     1
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          35.560            1.6       8             256       1.60    978
# 1          39.624            2.0       4             256       2.20    634
# 2          39.624            2.7       8             256       2.20    946
# 3          33.782            1.6       8             128       1.22   1244
# 4          39.624            1.8       8             256       1.91    837

# %%
df[['Manufacturer']]
# Out:
#     Manufacturer
# 0           Acer
# 1           Dell
# 2           Dell
# 3           Dell
# 4             HP
# ..           ...
# 233       Lenovo
# 234      Toshiba
# 235       Lenovo
# 236       Lenovo
# 237      Toshiba
#
# [238 rows x 1 columns]

# %%
df['Screen_Size_cm']=np.round(df[['Screen_Size_cm']])

# %%
df[['Screen_Size_cm']]
# Out:
#      Screen_Size_cm
# 0              36.0
# 1              40.0
# 2              40.0
# 3              34.0
# 4              40.0
# ..              ...
# 233            36.0
# 234            34.0
# 235            30.0
# 236            40.0
# 237            36.0
#
# [238 rows x 1 columns]

# %%
count_dict = {}

for column_name in df:
    count = 0
    for value in df[column_name]:
        if pd.isnull(value):
            count += 1
    count_dict[column_name] = count

count_dict
# Out:
# {'Unnamed: 0': 0,
#  'Manufacturer': 0,
#  'Category': 0,
#  'Screen': 0,
#  'GPU': 0,
#  'OS': 0,
#  'CPU_core': 0,
#  'Screen_Size_cm': 4,
#  'CPU_frequency': 0,
#  'RAM_GB': 0,
#  'Storage_GB_SSD': 0,
#  'Weight_kg': 5,
#  'Price': 0}

# %%
df['Weight_kg'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 238 entries, 0 to 237
# Series name: Weight_kg
# Non-Null Count  Dtype
# --------------  -----
# 233 non-null    float64
# dtypes: float64(1)
# memory usage: 2.0 KB

# %%
for i in df:
    for j in df[i]:
        if pd.isnull(j):
           df[i].replace(j,'np.Nan')

# %%
missing_data = df.isnull()
for column in missing_data.columns.values.tolist():
    print (missing_data[column].value_counts())
    print("")
# Out:
# Unnamed: 0
# False    238
# Name: count, dtype: int64
#
# Manufacturer
# False    238
# Name: count, dtype: int64
#
# Category
# False    238
# Name: count, dtype: int64
#
# Screen
# False    238
# Name: count, dtype: int64
#
# GPU
# False    238
# Name: count, dtype: int64
#
# OS
# False    238
# Name: count, dtype: int64
#
# CPU_core
# False    238
# Name: count, dtype: int64
#
# Screen_Size_cm
# False    234
# True       4
# Name: count, dtype: int64
#
# CPU_frequency
# False    238
# Name: count, dtype: int64
#
# RAM_GB
# False    238
# Name: count, dtype: int64
#
# Storage_GB_SSD
# False    238
# Name: count, dtype: int64
#
# Weight_kg
# False    233
# True       5
# Name: count, dtype: int64
#
# Price
# False    238
# Name: count, dtype: int64

# %%
mean= df['Weight_kg'].mean()
mean
# Out:
# 1.8622317596566522

# %%
df['Weight_kg'].replace((np.nan,mean),inplace=True)

# %%
avg_weight=df['Weight_kg'].astype('float').mean(axis=0)
df["Weight_kg"].replace(np.nan, avg_weight, inplace=True)

# %%
df['Screen_Size_cm'].value_counts()
df['Screen_Size_cm'].replace(np.nan,40.0,inplace=True)

# %%
df['Weight_kg']=df['Weight_kg'].astype('float')

# %%
df['Screen_Size_cm']=df['Screen_Size_cm'].astype('float')

# %%
df[['Weight_kg','Screen_Size_cm']].dtypes
# Out:
# Weight_kg         float64
# Screen_Size_cm    float64
# dtype: object

# %%
df['Weight_kg'].value_counts().idxmax()
# Out:
# 2.2

# %%
df['Screen_Size_cm']=df['Screen_Size_cm']/2.54

# %%
df.rename(columns={'Screen_Size_cm':'Screen_Size_inches'},inplace=True)

# %%
df['Weight_kg']=df['Weight_kg']*2.205

# %%
df.rename(columns={'Weight_kg':'Weight_pound'},inplace=True)

# %%
df['CPU_frequency']=df['CPU_frequency']/df['CPU_frequency'].max()

# %%
df['CPU_frequency']
# Out:
# 0      0.551724
# 1      0.689655
# 2      0.931034
# 3      0.551724
# 4      0.620690
#          ...
# 233    0.896552
# 234    0.827586
# 235    0.896552
# 236    0.862069
# 237    0.793103
# Name: CPU_frequency, Length: 238, dtype: float64

# %%
bins=np.linspace(min(df['Price']),max(df['Price']),4)
bins
# Out:
# array([ 527.        , 1621.33333333, 2715.66666667, 3810.        ])

# %%
cols=['min','medium','high']

# %%
df['Price']=pd.cut(df['Price'],bins,labels=cols, include_lowest=True)

# %%
plt.bar(cols, df["Price"].value_counts())
plt.xlabel("Price")
plt.ylabel("count")
plt.title("Price bins")
# Out:
# Text(0.5, 1.0, 'Price bins')

# %%
dummy_var=pd.get_dummies(df['Screen'],prefix='Screen')
pd.concat([df,dummy_var],axis=1)
# Out:
#      Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0             0         Acer         4  IPS Panel    2   1         5
# 1             1         Dell         3    Full HD    1   1         3
# 2             2         Dell         3    Full HD    1   1         7
# 3             3         Dell         4  IPS Panel    2   1         5
# 4             4           HP         4    Full HD    2   1         7
# ..          ...          ...       ...        ...  ...  ..       ...
# 233         233       Lenovo         4  IPS Panel    2   1         7
# 234         234      Toshiba         3    Full HD    2   1         5
# 235         235       Lenovo         4  IPS Panel    2   1         5
# 236         236       Lenovo         3    Full HD    3   1         5
# 237         237      Toshiba         3    Full HD    2   1         5
#
#      Screen_Size_inches  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pound  \
# ...

# %%
df = df.drop('Screen', axis=1)

# %%
df
# Out:
#      Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_inches  \
# 0             0         Acer         4    2   1         5            5.580011
# 1             1         Dell         3    1   1         3            6.200012
# 2             2         Dell         3    1   1         7            6.200012
# 3             3         Dell         4    2   1         5            5.270011
# 4             4           HP         4    2   1         7            6.200012
# ..          ...          ...       ...  ...  ..       ...                 ...
# 233         233       Lenovo         4    2   1         7            5.580011
# 234         234      Toshiba         3    2   1         5            5.270011
# 235         235       Lenovo         4    2   1         5            4.650009
# 236         236       Lenovo         3    3   1         5            6.200012
# 237         237      Toshiba         3    2   1         5            5.580011
#
# ...
