# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
filepath='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df=pd.read_csv(filepath)
df
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %%
df['gas'].corr(df['city-L/100km'])
# Out:
# 0.2412823477404382

# %%
df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
df[['bore','stroke','compression-ratio','horsepower']].dtypes
# Out:
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# dtype: object

# %%
sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 53375.94500403877)

# %%
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x='highway-mpg',y='price',data=df)
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %%
df[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sns.regplot(x='peak-rpm',y='price',data=df)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='price'>

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
df[['price','stroke']].corr()
# Out:
#           price   stroke
# price   1.00000  0.08231
# stroke  0.08231  1.00000

# %%
sns.regplot(x='stroke',y='price',data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
sns.boxplot(x='body-style',y='price',data=df)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x='engine-location', y='price',data=df)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %%
sns.boxplot(x='drive-wheels',y='price',data=df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
df.describe(include='object')
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'}, inplace=True)
drive_wheels_counts
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts.head(10)
# Out:
#                  count
# engine-location
# front              198
# rear                 3

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one = df[['drive-wheels','body-style','price']]
df_group_one
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %%
a=df_group_one.groupby(['drive-wheels'],as_index=False)

# %%
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
pivot_tab=grouped_test1.pivot(index='drive-wheels',columns='body-style')
pivot_tab
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grouped_pivot = pivot_tab.fillna(0) #fill missing values with 0
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
z=df[['body-style','price']]
z_group=z.groupby(['body-style'],as_index=False).mean()
z_group
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
plt.pcolor(grouped_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
df[['length','price']].corr()
# Out:
#           length     price
# length  1.000000  0.690628
# price   0.690628  1.000000

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5846418222655081  with a P-value of P = 8.076488270732885e-20

# %%
p_c,p_v=stats.pearsonr(df['horsepower'],df['price'])
p_c,p_v
# Out:
# (0.809574567003656, 6.369057428259557e-48)

# %%
pearson_c_l,p_val_l=stats.pearsonr(df['length'],df['price'])
pearson_c_l,p_val_l
# Out:
# (0.690628380448364, 8.016477466158868e-30)

# %%
p_w_c,p_w=stats.pearsonr(df['width'],df['price'])
p_w_c,p_w
# Out:
# (0.7512653440522674, 9.20033551048144e-38)

# %%
p_e_c,p_e=stats.pearsonr(df['engine-size'],df['price'])
p_e_c,p_e
# Out:
# (0.8723351674455185, 9.265491622198793e-64)

# %%
p_b_c,p_b=stats.pearsonr(df['bore'],df['price'])
p_b_c,p_b
# Out:
# (0.5431553832626602, 8.049189483935315e-17)

# %%
p_city_c,p_city=stats.pearsonr(df['city-mpg'],df['price'])
p_city_c,p_city
# Out:
# (-0.6865710067844677, 2.3211320655676474e-29)

# %%
pearson_coef, p_value = stats.pearsonr(df['highway-mpg'], df['price'])
print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value )
# Out:
# The Pearson Correlation Coefficient is -0.7046922650589529  with a P-value of P =  1.7495471144476463e-31

# %% [markdown]
# ### New Data SET

# %%
filepath="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod2.csv"
df=pd.read_csv(filepath,header=0)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  \
# 0             0           0         Acer         4    2   1         5
# 1             1           1         Dell         3    1   1         3
# 2             2           2         Dell         3    1   1         7
# 3             3           3         Dell         4    2   1         5
# 4             4           4           HP         4    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0       0.551724       8             256        3.52800
# 1              15.6       0.689655       4             256        4.85100
# 2              15.6       0.931034       8             256        4.85100
# 3              13.3       0.551724       8             128        2.69010
# 4              15.6       0.620690       8             256        4.21155
#
#    Price Price-binned  Screen-Full_HD  Screen-IPS_panel
# ...

# %%
sns.regplot(x='CPU_frequency',y='Price',data=df)
# Out:
# <Axes: xlabel='CPU_frequency', ylabel='Price'>

# %%
sns.regplot(x='Screen_Size_inch',y='Price',data=df)
# Out:
# <Axes: xlabel='Screen_Size_inch', ylabel='Price'>

# %%
sns.regplot(x='Weight_pounds',y='Price',data=df)
# Out:
# <Axes: xlabel='Weight_pounds', ylabel='Price'>

# %%
df[['Weight_pounds','Screen_Size_inch','CPU_frequency','Price']].corr()
# Out:
#                   Weight_pounds  Screen_Size_inch  CPU_frequency     Price
# Weight_pounds          1.000000          0.797534       0.066522 -0.050312
# Screen_Size_inch       0.797534          1.000000      -0.000948 -0.110644
# CPU_frequency          0.066522         -0.000948       1.000000  0.366666
# Price                 -0.050312         -0.110644       0.366666  1.000000

# %%
sns.boxplot(x='Category',y='Price',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Price'>

# %%
#GPU", "OS", "CPU_core", "RAM_GB", "Storage_GB_SSD"
sns.boxplot(x='GPU',y='Price',data=df)
# Out:
# <Axes: xlabel='GPU', ylabel='Price'>

# %%
sns.boxplot(x='OS',y='Price',data=df)
# Out:
# <Axes: xlabel='OS', ylabel='Price'>

# %%
sns.boxplot(x='CPU_core',y='Price',data=df)
# Out:
# <Axes: xlabel='CPU_core', ylabel='Price'>

# %%
sns.boxplot(x='RAM_GB',y='Price',data=df)
# Out:
# <Axes: xlabel='RAM_GB', ylabel='Price'>

# %%
sns.boxplot(x='Storage_GB_SSD',y='Price',data=df)
# Out:
# <Axes: xlabel='Storage_GB_SSD', ylabel='Price'>

# %%
df.describe(include='all')
df.describe(include='object')
# Out:
#        Manufacturer Price-binned
# count           238          238
# unique           11            3
# top            Dell          Low
# freq             71          160

# %%
data=df[['GPU', 'CPU_core','Price']]
data
# Out:
#      GPU  CPU_core  Price
# 0      2         5    978
# 1      1         3    634
# 2      1         7    946
# 3      2         5   1244
# 4      2         7    837
# ..   ...       ...    ...
# 233    2         7   1891
# 234    2         5   1950
# 235    2         5   2236
# 236    3         5    883
# 237    2         5   1499
#
# [238 rows x 3 columns]

# %%
grouped_data_1=data.groupby(['GPU','CPU_core'],as_index=False).mean()
pivot_table=grouped_data_1.pivot(index='GPU',columns='CPU_core')
plt.pcolor(pivot_table,cmap='RdBu')
plt.colorbar()
plt.show()

# %%
cor_person_coef,p_value=stats.pearsonr(df['GPU'],df['Price'])
cor_person_coef,p_value
# Out:
# (0.2882981988881428, 6.166949698364282e-06)

# %%
cor_person_coef,p_value=stats.pearsonr(df['CPU_core'],df['Price'])
cor_person_coef,p_value
# Out:
# (0.45939777733551157, 7.912950127009034e-14)
